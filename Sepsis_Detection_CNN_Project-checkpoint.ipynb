# %% [markdown]
# # 🧬 Biomedical Sustainability Project
# ### CNN-Based Early Sepsis Detection from Medical Images
#
# **Team Members:**
# 1. Ashish Gautam
# 2. Aarya Goel
# 3. Manisha Sharma
# 4. Yogesh Mishra
# 5. Dhruv Gupta
#
# **College:** Raj Kumar Goel Institute of Technology
# **Mentor:** [Dr. Veena Bharti]

# %% [markdown]
# ## 📘 Introduction
#
# Sepsis is a life-threatening condition caused by the body’s extreme response to an infection.
# Early detection of sepsis can save lives and reduce the intensive energy and resource use of hospital care.
#
# In this project, a **Convolutional Neural Network (CNN)** is trained to detect early biomarkers of sepsis from medical images (e.g., X-rays, CT scans, or clinical photos).
# By providing an automated diagnosis system, we promote **sustainability in healthcare** through:
#
# - Reduced hospital stay durations 🏥
# - Lower medical equipment energy use ⚡
# - Decreased use of radiological scans and antibiotics 🌱

# %%
import torch

# %%
conda info --envs
# Out:
# # conda environments:
# #
# base                   C:\Users\ashis\anaconda3
# cnn_env              * C:\Users\ashis\anaconda3\envs\cnn_env
#                        C:\Users\ashis\miniconda3
#                        C:\Users\ashis\miniconda3\envs\cnn_env
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import models
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### 🧠 About the CNN Model
#
# We trained a Convolutional Neural Network (CNN) to detect early signs of Sepsis from medical images.
# The model learns spatial patterns (like color variations, texture, or shapes) that may correlate with infection-related changes.
#
# Key features:
# - Uses convolutional layers for feature extraction.
# - Batch normalization and ReLU activations improve stability.
# - A final fully-connected layer performs binary classification: *Sepsis* vs *Healthy*.

# %%
import os
print("📂 Current notebook path:", os.getcwd())
# Out:
# 📂 Current notebook path: C:\Users\ashis\OneDrive\Desktop\Sepsis_CNN_Project

# %%
import os
print("Model file exists:", os.path.exists("best_sepsis_cnn.pth"))
# Out:
# Model file exists: False

# %%
import os
print("Model file exists:", os.path.exists("best_sepsis_cnn.pth"))
# Out:
# Model file exists: False

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SepsisCNN(nn.Module):
    def __init__(self, num_classes=2):
        super(SepsisCNN, self).__init__()
        
        # Match the architecture used during training
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        
        # The number 1548800 must match your trained model
        self.fc1 = nn.Linear(1548800, 64)
        self.fc2 = nn.Linear(64, num_classes)
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
import os
print("Model file exists:", os.path.exists("best_sepsis_cnn.pth"))
# Out:
# Model file exists: True

# %%
model = SepsisCNN(num_classes=2)
model.load_state_dict(torch.load("best_sepsis_cnn.pth", map_location=torch.device("cpu")))
model.eval()
print("✅ Model loaded successfully.")
# Out:
# ✅ Model loaded successfully.

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (5.49.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.120.4)
# Requirement already satisfied: ffmpy in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.6.4)
# Requirement already satisfied: gradio-client==1.13.3 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (1.0.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (2.0.1)
# Requirement already satisfied: orjson~=3.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (3.11.4)
# Requirement already satisfied: packaging in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (2.11.10)
# Requirement already satisfied: pydub in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.14.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.49.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio-client==1.13.3->gradio) (2025.9.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.3)
# Requirement already satisfied: certifi in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.17.0)
# Requirement already satisfied: shellingham in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (0.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.3.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: colorama in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ashis\anaconda3\envs\cnn_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import gradio as gr
print("✅ Gradio is working correctly inside this kernel!")
# Out:
# ✅ Gradio is working correctly inside this kernel!

# %%
import gradio as gr
import torch
import torchvision.transforms as transforms
from PIL import Image
import torch.nn as nn

# ------------------------------
# 1️⃣ Define CNN Model
# ------------------------------
class SepsisCNN(nn.Module):
    def __init__(self, num_classes=2):
        super(SepsisCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        
        # ✅ Match trained model input size
        self.fc1 = nn.Linear(1548800, 64)
        self.fc2 = nn.Linear(64, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# ------------------------------
# 2️⃣ Load Model
# ------------------------------
model = SepsisCNN(num_classes=2)
model.load_state_dict(torch.load("best_sepsis_cnn.pth", map_location=torch.device("cpu")))
model.eval()

# ------------------------------
# 3️⃣ Define Transform (MATCH TRAINING)
# ------------------------------
transform = transforms.Compose([
    transforms.Resize((880, 880)),   # ✅ this must match training image size
    transforms.ToTensor(),
])

# ------------------------------
# 4️⃣ Prediction Function
# ------------------------------
def predict_image(img):
    img_t = transform(img).unsqueeze(0)
    with torch.no_grad():
        outputs = model(img_t)
        _, predicted = torch.max(outputs, 1)
    classes = ['Normal', 'Sepsis Detected']
    return classes[predicted.item()]

# ------------------------------
# 5️⃣ Build Gradio App
# ------------------------------
app = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="🧠 CNN-based Sepsis Detection",
    description="Upload a medical image to detect signs of sepsis."
)

# ------------------------------
# 6️⃣ Launch App
# ------------------------------
import nest_asyncio
nest_asyncio.apply()
app.launch()
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_15344\3532819599.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_sepsis_cnn.pth", map_location=torch.device("cpu")))
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
